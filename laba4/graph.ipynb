# %%
import matplotlib.pyplot as plt

# %%
f = open('res1/coord1_0')
x = []
y = []
arr = f.readlines()
for i in arr:
    a, b, c = i.split(',')
    x.append(float(b))
    y.append(float(c))

plt.plot(x, y)
f.close()
f = open('res1/coord0_1')
x = []
y = []
arr = f.readlines()
for i in arr:
    a, b, c = i.split(',')
    x.append(float(b))
    y.append(float(c))

plt.plot(x, y)
f.close()

f = open('res1/coord-1_0')
x = []
y = []
arr = f.readlines()
for i in arr:
    a, b, c = i.split(',')
    x.append(float(b))
    y.append(float(c))

plt.plot(x, y)
f.close()

f = open('res1/coord0_-1')
x = []
y = []
arr = f.readlines()
for i in arr:
    a, b, c = i.split(',')
    x.append(float(b))
    y.append(float(c))

plt.plot(x, y)
f.close()
