# %%
import matplotlib.pyplot as plt
import numpy as np
from math import sin, cos

# %%
xh = np.linspace(0, 10, 100)
a = 0.2
b = 0.5
c = 0.1
for i in range(1):
    f = open(f'res4_2/task4')
    x = []
    y = []
    arr = f.readlines()
    for i in arr:
        a1, b1, c1 = i.split(',')
        x.append(float(b1))
        y.append(float(c1))

    plt.plot(x, y)
    f.close()
plt.plot([cos(x) for x in xh], [sin(y) for y in xh])
# plt.scatter([0, 0, 0.4, -0.4], [0.4, -0.4, 0, 0])

# %%
a1 = 0.2
b1 = 0.8
xh = np.linspace(0, 10, 10000)
for i in range(1):
    f = open(f'res3/task3')
    x = []
    y = []
    arr = f.readlines()
    for i in arr:
        a, b, c = i.split(',')
        x.append(float(b))
        y.append(float(c))

    plt.plot(x, y)
    f.close()
# plt.plot([a1 + b1 * sin(2 * t) for t in xh], [b1 * sin(t) for t in xh])

# %%
for i in range(5):
    f = open(f'res1_1/task1{i}')
    x = []
    y = []
    arr = f.readlines()
    for i in arr:
        a, b, c = i.split(',')

        x.append(float(b))
        y.append(float(c))

    plt.plot(x, y)
    f.close()
